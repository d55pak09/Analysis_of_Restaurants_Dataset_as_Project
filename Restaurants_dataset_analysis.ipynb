# %% [markdown]
# ## Analysis of Restaurants Datasets

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset
df = pd.read_csv('Restaurent.csv')

# make a copy of data
data=df.copy()
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# ## Explore Data

# %%
# show sample of data
data.sample(5)
# Out:
#       Restaurant ID      Restaurant Name  Country Code       City  \
# 5545         304469        Tirath Sweets             1  New Delhi
# 4171       18408050           Fish Point             1  New Delhi
# 6660           9458  Anjlika Pastry Shop             1  New Delhi
# 2479       18424018    The Shooters Cafe             1     Mohali
# 9264        2800757         Bake My Wish             1      Vizag
#
#                                                 Address        Locality  \
# 5545      Main Road, Main Market, Moti Nagar, New Delhi      Moti Nagar
# 4171           4164, Urdu Bazar, Jama Masjid, New Delhi     Jama Masjid
# 6660                   F-146, Rajouri Garden, New Delhi  Rajouri Garden
# 2479  SCO 654,Himalaya Marg Road, Sector 70, Mohali,...       Sector 70
# 9264   4-70-4, Opposite NCC Canteen, Lawsons Bay, Vizag     Lawsons Bay
#
#                Locality Verbose  Longitude   Latitude  \
# 5545      Moti Nagar, New Delhi  77.140071  28.657079
# ...

# %%
# showing information of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# round the columns till two decimal places
data = round(data,2)
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# #### Numeric Columns

# %%
numeric_data = data.select_dtypes(include=['int','float'])
numeric_data
# Out:
#       Restaurant ID  Country Code  Longitude  Latitude  Average Cost for two  \
# 0           6317637           162     121.03     14.57                  1100
# 1           6304287           162     121.01     14.55                  1200
# 2           6300002           162     121.06     14.58                  4000
# 3           6318506           162     121.06     14.59                  1500
# 4           6314302           162     121.06     14.58                  1500
# ...             ...           ...        ...       ...                   ...
# 9546        5915730           208      28.98     41.02                    80
# 9547        5908749           208      29.04     41.01                   105
# 9548        5915807           208      29.03     41.06                   170
# 9549        5916112           208      29.04     41.06                   120
# 9550        5927402           208      29.03     40.98                    55
#
#       Price range  Aggregate rating  Votes
# ...

# %% [markdown]
# #### Categorical Columns

# %%
# showing categorical columns

categorical_cols = data.select_dtypes(include='object').head(5)
categorical_cols
# Out:
#           Restaurant Name              City  \
# 0        Le Petit Souffle       Makati City
# 1        Izakaya Kikufuji       Makati City
# 2  Heat - Edsa Shangri-La  Mandaluyong City
# 3                    Ooma  Mandaluyong City
# 4             Sambo Kojin  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose  \
# ...

# %%
categorical_cols['Restaurant Name'].unique()
# Out:
# array(['Le Petit Souffle', 'Izakaya Kikufuji', 'Heat - Edsa Shangri-La',
#        'Ooma', 'Sambo Kojin'], dtype=object)

# %% [markdown]
# ## Handling missing values

# %%
from sklearn.impute import SimpleImputer

# filling missing values
impute = SimpleImputer(strategy='most_frequent')
data[['Cuisines']] = impute.fit_transform(data[['Cuisines']])

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Label Encoding

# %%
# import category_encoders as ce
# from sklearn.preprocessing import LabelEncoder
# # Initialize the encoder
# # encoder = LabelEncoder()

# cat_cols = ['Locality','Locality Verbose','Switch to order menu']
# # Initialize the encoder
# encoder = ce.OrdinalEncoder(cols=cat_cols)

# # Apply the encoding to the DataFrame
# data_encoded = encoder.fit_transform(data)

# data_encoded

# %%
# data_encoded['Is delivering now'].values

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Determine the top three most common cuisines in the dataset.

# %%
#1 Determine the top three most common cuisines in the dataset.
cuisines_count = data['Cuisines'].value_counts()

# top 3 cuisines
top_cuisines = cuisines_count.head(4)
top_cuisines.to_frame()
# Out:
#                        Cuisines
# North Indian                945
# North Indian, Chinese       511
# Chinese                     354
# Fast Food                   354

# %% [markdown]
# #### Calculate the percentage of restaurants that serve each of the top cuisines.

# %%
#2 Calculate the percentage of restaurants that serve each of the top cuisines.

# Calculate the total number of restaurants
total_restaurants = len(data['Restaurant Name'])

# Calculate the percentage of restaurants for each cuisine
cuisine_percentages = (top_cuisines / total_restaurants) * 100

cuisine_percentages.to_frame()
# Out:
#                        Cuisines
# North Indian           9.894252
# North Indian, Chinese  5.350225
# Chinese                3.706418
# Fast Food              3.706418

# %% [markdown]
# #### Identify the city with the highest number of restaurants in the dataset

# %%
# Use value_counts() to count the number of restaurants in each city
restaurant_counts = data['City'].value_counts()

# Get the city with the highest number of restaurants
city_with_highest_restaurants = restaurant_counts.idxmax()

# Get the count of restaurants in the city with the highest number of restaurants
highest_restaurants_count = restaurant_counts.max()
print(f"The city with the highest number of restaurants is: {city_with_highest_restaurants}")
print(f"The number of restaurants in this city is: {highest_restaurants_count}")
# Out:
# The city with the highest number of restaurants is: New Delhi
# The number of restaurants in this city is: 5473

# %% [markdown]
# ######  2. Calculate the average rating for restaurants in each city.

# %%
#  Top 10 average rating restaurants with city

data['city with rating'] = data['City'] +' '+ data['Restaurant Name']+' '+data['Rating text']
data['city with rating'].value_counts().sort_values(ascending=False).head(10).to_frame()
# Out:
#                                        city with rating
# New Delhi Domino's Pizza Average                     43
# New Delhi Cafe Coffee Day Average                    42
# New Delhi Green Chick Chop Average                   29
# New Delhi Subway Average                             25
# New Delhi McDonald's Average                         17
# New Delhi Giani Average                              16
# New Delhi McDonald's Good                            16
# New Delhi Keventers Average                          12
# New Delhi Republic of Chicken Average                11
# Gurgaon Subway Average                               11

# %% [markdown]
# ###### 3. Determine the city with the highest average rating.

# %%
rating_mapping = {
    'Excellent': 5,
    'Very Good': 4,
    'Good': 3,
    'Average': 2,
    'Poor': 1,
}

# Map the string ratings to numeric values using the mapping
df['Numeric_Rating'] = df['Rating text'].map(rating_mapping)

# Group the DataFrame by 'City' and calculate the mean numeric rating for each city
average_ratings_by_city = df.groupby('City')['Numeric_Rating'].mean()

# Get the city with the highest average rating
city_with_highest_avg_rating = average_ratings_by_city.idxmax()

# Get the highest average rating value
highest_avg_rating = average_ratings_by_city.max()

print(f"The city with the highest average rating is: {city_with_highest_avg_rating}",'\n')
print(f"The highest average rating is: {highest_avg_rating}")
# Out:
# The city with the highest average rating is: Beechworth
#
# The highest average rating is: 5.0

# %% [markdown]
# #### Create a histogram or bar chart to visualize the distribution of price rangesamong the restaurants.

# %%
# Assuming your data is in a pandas DataFrame called 'data'

# Define the broad price range categories
price_categories = ['Low', 'Medium', 'High']

# Group the 'Price range' column into the defined categories
df['Price Category'] = pd.cut(df['Price range'], bins=[0, 2, 3, float('inf')], labels=price_categories)

# Create a bar plot to visualize the count of restaurants in each price category
sns.barplot(data=df, x='Price Category',y='Restaurant ID')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# #### Calculate the percentage of restaurants in each price range category

# %%
# see all unique values of price range
my_var =  df['Price Category'].value_counts()
print(my_var,'\n')

low = round(my_var['Low']/my_var.sum()*100,2)
print('Percentage of low range restaurents',low)

medium = round(my_var['Medium']/my_var.sum()*100,2)
print('Percentage of low medium restaurents',medium)

high = round(my_var['High']/my_var.sum()*100,2)
print('Percentage of low high restaurents',high)
# Out:
# Low       7557
# Medium    1408
# High       586
# Name: Price Category, dtype: int64
#
# Percentage of low range restaurents 79.12
# Percentage of low medium restaurents 14.74
# Percentage of low high restaurents 6.14

# %%
# Define the broad percentage categories
percentage_categories = ['low', 'medium', 'high']
values = [79.12, 14.74, 6.14]

# Create the pie chart
plt.pie(values, labels=percentage_categories, autopct='%1.1f%%')

# Add a title
plt.title('price range category')

# Display the chart
plt.show()

# %% [markdown]
# #### Determine the percentage of restaurants that offer online delivery.

# %%
# showing dnumber of counts that have online delivery or not 
values_diff =  df['Has Online delivery'].value_counts()
print(values_diff,'\n')

# percentage of restaurents that offer online delivery
a = round(values_diff['Yes']/values_diff.sum()*100,2)

# print
print('Percentage of restaurents that offer online delivery',a)
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64
#
# Percentage of restaurents that offer online delivery 25.66

# %% [markdown]
# #### Compare the average ratings of restaurants with and without online delivery

# %%
average_ratings = df.groupby("Has Online delivery")["Aggregate rating"].mean()
average_ratings
# Out:
# Has Online delivery
# No     2.465296
# Yes    3.248837
# Name: Aggregate rating, dtype: float64

# %%
# Create the bar plot
plt.bar(average_ratings.index, average_ratings.values, color=['blue', 'orange'])

# Add labels and title
plt.xlabel("Has Online Delivery")
plt.ylabel("average_ratings")
plt.title("Comparison of Average Ratings for Restaurants with and without Online Delivery")

# Show the plot
plt.show()

# %% [markdown]
# #### Analyze the distribution of aggregate ratings and determine the most common rating range.

# %%
# The distribution of aggregate ratings
distribution_of_aggregate_ratings = df['Aggregate rating'].describe().to_frame()
distribution_of_aggregate_ratings
# Out:
#        Aggregate rating
# count       9551.000000
# mean           2.666370
# std            1.516378
# min            0.000000
# 25%            2.500000
# 50%            3.200000
# 75%            3.700000
# max            4.900000

# %%
# Top most 3 common rating range.
df['Aggregate rating'].value_counts().head(3).to_frame()
# Out:
#      Aggregate rating
# 0.0              2148
# 3.2               522
# 3.1               519

# %% [markdown]
# #### Calculate the average number of votes received by restaurants.

# %%
#  the average number of votes received by restaurants
df['Votes'].mean()
# Out:
# 156.909747670401

# %% [markdown]
# #### Identify the most common combinations of cuisines in the dataset.

# %%
#1 the most common cuisines in the dataset.
cuisines_count = data['Cuisines'].value_counts()

# top 10 cuisines 
top_cuisines = cuisines_count.head(10)
print(top_cuisines,'\n')

print(' Top 3 cuisines combination')
print(' North Indian, Chinese','\n','North Indian, Mughlai','\n','North Indian, Mughlai, Chinese')
# Out:
# North Indian                      945
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64
#
#  Top 3 cuisines combination
#  North Indian, Chinese
#  North Indian, Mughlai
#  North Indian, Mughlai, Chinese

# %% [markdown]
# #### Determine if certain cuisine combinations tend to have higher ratings

# %%
# combine the necessary columns cuisines and rating text
df['cuisine combinations '] = df['Cuisines']+' '+ df['Rating text']

df['cuisine combinations '].value_counts().head(10)
# Out:
# North Indian Not rated                    444
# North Indian Average                      366
# North Indian, Chinese Average             303
# North Indian, Mughlai Average             185
# Chinese Average                           151
# Fast Food Average                         151
# Cafe Average                              132
# Chinese Not rated                         130
# Fast Food Not rated                       126
# North Indian, Mughlai, Chinese Average    122
# Name: cuisine combinations , dtype: int64

# %%
# Top three cuisines combination with average rating

# North Indian, Chinese Average 
# North Indian, Mughlai Average
# North Indian, Mughlai, Chinese Average

# %% [markdown]
# #### Identify if there are any restaurant chains present in the dataset.

# %%
# Group restaurants by their name and count occurrences
restaurant_counts = df['Restaurant Name'].value_counts()

# Filter for restaurants with more than one occurrence (potential chains)
restaurant_chains = restaurant_counts[restaurant_counts > 1]

# Display the potential restaurant chains
print("Potential restaurant chains:")
print(restaurant_chains)
# Out:
# Potential restaurant chains:
# Cafe Coffee Day       83
# Domino's Pizza        79
# Subway                63
# Green Chick Chop      51
# McDonald's            48
#                       ..
# Town Hall              2
# Halki Aanch            2
# Snack Junction         2
# Delhi Biryani Hut      2
# Beliram Degchiwala     2
# Name: Restaurant Name, Length: 734, dtype: int64

# %% [markdown]
# #### Analyze the ratings and popularity of different restaurant chains.

# %%
 # Group restaurants by their name and count occurrences
df['new_rating'] = df['Restaurant Name'] +' '+ df['Rating text']

rating_var = df['new_rating'].value_counts()

# Filter for restaurants with rating text more than one occurrence (potential chains)
rating_var = rating_var[rating_var > 1]

# Display the potential rating_var
print("ratings of different restaurant chains:")
print(rating_var)


# the most commen rating is average of different restaurants chains
# Out:
# ratings of different restaurant chains:
# Cafe Coffee Day Average             59
# Domino's Pizza Average              53
# Subway Average                      43
# Green Chick Chop Average            40
# McDonald's Average                  27
#                                     ..
# Baked Buns Good                      2
# Shri Ram Restaurant Average          2
# Aggarwal Sweet Corner Average        2
# Nando's Good                         2
# Chawla Family Restaurant Average     2
# Name: new_rating, Length: 585, dtype: int64

# %% [markdown]
# #### Analyze the text reviews to identify the most common positive and negative keywords

# %%
# showing the unique values of columns
df['Rating text'].unique()
# counting the values
df['Rating text'].value_counts()
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %% [markdown]
# #### Identify the restaurants with the highest and lowest number of votes.

# %%
# Find the restaurant with the highest number of votes
restaurant_highest_votes = data.loc[data['Votes'].idxmax()]

# Find the restaurant with the lowest number of votes
restaurant_lowest_votes = data.loc[data['Votes'].idxmin()]

# Print the results
print("Restaurant with the highest number of votes:")
print(restaurant_highest_votes)

print("\nRestaurant with the lowest number of votes:")
print(restaurant_lowest_votes)
# Out:
# Restaurant with the highest number of votes:
# Restaurant ID                                                       51705
# Restaurant Name                                                      Toit
# Country Code                                                            1
# City                                                            Bangalore
# Address                 298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# Locality                                                      Indiranagar
# Locality Verbose                                   Indiranagar, Bangalore
# Longitude                                                           77.64
# Latitude                                                            12.98
# Cuisines                                         Italian, American, Pizza
# Average Cost for two                                                 2000
# Currency                                               Indian Rupees(Rs.)
# ...
